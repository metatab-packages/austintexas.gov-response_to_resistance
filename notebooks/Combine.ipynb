# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %%
pkg = mp.jupyter.open_package() # Must be built package. 

pkg
# Out:
# # Response to Resistance
# `austintexas.gov-response_to_resistance-1.1.4` Last Update: 2020-06-11T19:32:36
#
# _Austin Police Department response to police resistance incidents._
#
#
# This data package collects multiple years of the Response to Resistance dataset
# from the Austin, TX Police department. It includes each of the four source
# files and a fifth file that combines the four source files.
#
# ## Processing & Caveats
#
# The source files, one year of data per file, have slightly different columns,
# so in the combined file there are some columns which will not have data across
# all years. These columns are:
#
# * census_tract
# * county
# * location_1
# * zip
# * county_description
#
# The combined file also has a set of dummy variables for each of the values of
# the `subject_resistance` variable. The categories for `subject_resistance`
# change from year to year, and some codes from earlier years are "expired" in
# later years. The expiration tags have been removed, so the dummy variables mix
# expired and unexpired codes. This is because there are many
# `subject_resistance` values that only have expired codes in them. The original
# values etained in `subject_resistance`
#
# It appears that the earlier two years used a wide range of detailed codes, such
# as "firearm" or "edged weapon" which the later years have collapsed into
# "agressive_resistance", "defensive resistance" and "passive resistance", with
# out a definite cutoffdate for the transition. The image below shows True values for the dummy variables in yellow.
#
# <img src="http://library.metatab.org/austintexas.gov-response_to_resistance-1.1.2/docs/sr_dummy_coverage.png" width='800'>
#
# ## Police Data Collection
#
# This package is part of the [San Diego Data Library's Police Data Collection](https://github.com/metatab-packages/policedata-collection)
# ## Documentation Links
#
# * [Data Dictionary](https://data.austintexas.gov/Public-Safety/GUIDE-2017-R2R/27tg-e4dt/data) A spreadsheet with field definitions, for 2017
# * [R2R Datasets](https://data.austintexas.gov/browse?q=Response+To+Resistence&sortBy=relevance&page=1) A search on the Austin open data site for R2R datasets.
#
#
# ## Images
#
# [![doc_img](docs/sr_dummy_coverage.png "Dummy Variable Coverage")](docs/sr_dummy_coverage.png)
#
# True Values for Subject Resistance Dummy Variables by Date
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [r2r_2015](data/r2r_2015.csv)**. Response to Resistance, 2015
# * ** [r2r_2016](data/r2r_2016.csv)**. Response to Resistance, 2016
# * ** [r2r_2017](data/r2r_2017.csv)**. Response to Resistance, 2017
# * ** [r2r_2018](data/r2r_2018.csv)**. Response to Resistance, 2018
# * ** [r2r_2015_2018](data/r2r_2015_2018.csv)**. Combined R2R files, 2015 to 2018

# %%
pkg.resource('r2r_2015').url
# Out:
# 'data/r2r_2015.csv'

# %%
df = pkg.resource('r2r_2015').row_generator.dataframe()
df.head().T
# Out:
#                                                                     0  \
# rin                                                            154619
# primary_key                                                 201510652
# date_occurred                                     2015-01-01 00:00:00
# time_occurred                                                    0220
# location                                        E 6TH ST / TRINITY ST
# area_command                                                       GE
# nature_of_contact                                      VIEWED OFFENSE
# reason_desc                    NECESSARY TO EFFECT ARREST / DETENTION
# r2r_level                                                           3
# master_subject_id                                459228703: 201510652
# subject_sex                                                         M
# subject_race                                                        W
# subject_ethnicity                                                   N
# subject_conduct_desc       SUSPECTED UNDER INFLUENCE OF ALCOHOL/DRUGS
# subject_resistance                    EMPTY HAND DEFENSIVE RESISTANCE
# weapon_used_1                 WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
# weapon_used_2                                                     NaN
# weapon_used_3                                                     NaN
# weapon_used_4                                                     NaN
# weapon_used_5                                                     NaN
# number_shots                                                      NaN
# subject_effects                           NO COMPLAINT OF INJURY/PAIN
# effect_on_officer                         NO COMPLAINT OF INJURY/PAIN
# officer_organization_desc                     GEORGE 600 REG I PATROL
# officer_commission_date                           2013-05-17 00:00:00
# officer_yrs_of_service                                              2
# x_coordinate                                              3.11542e+06
# y_coordinate                                              1.00704e+07
# council_district                                                    9
#
#                                                                            1  \
# rin                                                                   154620
# primary_key                                                        201510652
# date_occurred                                            2015-01-01 00:00:00
# time_occurred                                                           0225
# location                                               E 6TH ST / TRINITY ST
# area_command                                                              GE
# nature_of_contact                                             VIEWED OFFENSE
# reason_desc                           NECESSARY TO EFFECT ARREST / DETENTION
# r2r_level                                                                  3
# master_subject_id                                       459228703: 201510652
# subject_sex                                                                M
# subject_race                                                               W
# subject_ethnicity                                                          N
# subject_conduct_desc              SUSPECTED UNDER INFLUENCE OF ALCOHOL/DRUGS
# subject_resistance         EMPTY HAND ACTIVE AGGRESSION; EMPTY HAND DEFEN...
# weapon_used_1                        WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
# weapon_used_2                                                            NaN
# weapon_used_3                                                            NaN
# weapon_used_4                                                            NaN
# weapon_used_5                                                            NaN
# number_shots                                                             NaN
# subject_effects                                                 MINOR INJURY
# effect_on_officer                                NO COMPLAINT OF INJURY/PAIN
# officer_organization_desc                            GEORGE 700 REG I PATROL
# officer_commission_date                                  2002-05-10 00:00:00
# officer_yrs_of_service                                                    13
# x_coordinate                                                     3.11542e+06
# y_coordinate                                                     1.00704e+07
# council_district                                                           9
#
#                                                                     2  \
# rin                                                            155009
# primary_key                                                 201510652
# date_occurred                                     2015-01-01 00:00:00
# time_occurred
# location                                        E 6TH ST / TRINITY ST
# area_command                                                       GE
# nature_of_contact                                      VIEWED OFFENSE
# reason_desc                    NECESSARY TO EFFECT ARREST / DETENTION
# r2r_level                                                           3
# master_subject_id                                459228703: 201510652
# subject_sex                                                         M
# subject_race                                                        W
# subject_ethnicity                                                   N
# subject_conduct_desc       SUSPECTED UNDER INFLUENCE OF ALCOHOL/DRUGS
# subject_resistance                    EMPTY HAND DEFENSIVE RESISTANCE
# weapon_used_1                 WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
# weapon_used_2                                                     NaN
# weapon_used_3                                                     NaN
# weapon_used_4                                                     NaN
# weapon_used_5                                                     NaN
# number_shots                                                      NaN
# subject_effects                           NO COMPLAINT OF INJURY/PAIN
# effect_on_officer                         NO COMPLAINT OF INJURY/PAIN
# officer_organization_desc                     GEORGE 300 REG I PATROL
# officer_commission_date                           2012-11-30 00:00:00
# officer_yrs_of_service                                              2
# x_coordinate                                              3.11542e+06
# y_coordinate                                              1.00704e+07
# council_district                                                    9
#
#                                                                            3  \
# rin                                                                   154764
# primary_key                                                        201520457
# date_occurred                                            2015-01-02 00:00:00
# time_occurred                                                           0943
# location                                                        1900 FARO DR
# area_command                                                              HE
# nature_of_contact                                            DISPATCHED CALL
# reason_desc                                  TO RESTRAIN FOR SUBJECTS SAFETY
# r2r_level                                                                  3
# master_subject_id                                       356649076: 201520457
# subject_sex                                                                F
# subject_race                                                               W
# subject_ethnicity                                                          N
# subject_conduct_desc       EDP/MENTALLY UNSTABLE; SUSPECTED UNDER INFLUEN...
# subject_resistance         VERBAL RESISTANCE/AGGRESSION; EMPTY HAND ACTIV...
# weapon_used_1                        WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
# weapon_used_2                                                            NaN
# weapon_used_3                                                            NaN
# weapon_used_4                                                            NaN
# weapon_used_5                                                            NaN
# number_shots                                                             NaN
# subject_effects                                     COMPLAINT OF INJURY/PAIN
# effect_on_officer                                   COMPLAINT OF INJURY/PAIN
# officer_organization_desc                           HENRY 100 REG III PATROL
# officer_commission_date                                  2008-06-20 00:00:00
# officer_yrs_of_service                                                     7
# x_coordinate                                                     3.12426e+06
# y_coordinate                                                     1.00572e+07
# council_district                                                           3
#
#                                                                            4
# rin                                                                   154859
# primary_key                                                        201520457
# date_occurred                                            2015-01-02 00:00:00
# time_occurred                                                           0943
# location                                                        1900 FARO DR
# area_command                                                              HE
# nature_of_contact                                            DISPATCHED CALL
# reason_desc                                  IN CUSTODY, MAINTAINING CONTROL
# r2r_level                                                                  3
# master_subject_id                                       356649076: 201520457
# subject_sex                                                                F
# subject_race                                                               W
# subject_ethnicity                                                          N
# subject_conduct_desc       EDP/MENTALLY UNSTABLE; SUSPECTED UNDER INFLUEN...
# subject_resistance         VERBAL RESISTANCE/AGGRESSION; EMPTY HAND DEFEN...
# weapon_used_1                        WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
# weapon_used_2                                                            NaN
# weapon_used_3                                                            NaN
# weapon_used_4                                                            NaN
# weapon_used_5                                                            NaN
# number_shots                                                             NaN
# subject_effects                                     COMPLAINT OF INJURY/PAIN
# effect_on_officer                                NO COMPLAINT OF INJURY/PAIN
# officer_organization_desc                           HENRY 100 REG III PATROL
# officer_commission_date                                  2009-01-02 00:00:00
# officer_yrs_of_service                                                     6
# x_coordinate                                                     3.12426e+06
# y_coordinate                                                     1.00572e+07
# council_district                                                           3

# %%
doc = pkg

from itertools import zip_longest

headers = []

# This will iterate through columns in roughtly the same time from 
# each dataset. The prevents a case where, for insance, the last dataset has a new column
# in an early group ( say, 5th column ) but it will end up at the end of the combined columns. 
# Whith this technique, it will end up near the 5th position. 

columns = [list(c['header'] for c in r.columns()) for r in doc.resources() if r.name != 'r2r_2015_2018']

for col_headers in columns:

    for c in col_headers:
        if c not in headers:
            headers.append(c)
            
print(headers)
# Out:
# ['rin', 'primary_key', 'date_occurred', 'time_occurred', 'location', 'area_command', 'nature_of_contact', 'reason_desc', 'r2r_level', 'master_subject_id', 'subject_sex', 'subject_race', 'subject_ethnicity', 'subject_conduct_desc', 'subject_resistance', 'weapon_used_1', 'weapon_used_2', 'weapon_used_3', 'weapon_used_4', 'weapon_used_5', 'number_shots', 'subject_effects', 'effect_on_officer', 'officer_organization_desc', 'officer_commission_date', 'officer_yrs_of_service', 'x_coordinate', 'y_coordinate', 'council_district', 'census_tract', 'county', 'location_1', 'zip', 'county_description']

# %%
def update_columns(df, headers):
    
    t = pd.DataFrame()
    
    for h in headers:
        if h in df.columns:
            t[h] = df[h]
        else:
            t[h] = None
            
frames = [] 

for r in doc.resources():
    if r.name == 'r2r_2015_2018':
        continue
            
    df = r.dataframe(na_filter=True)
    
    
    update_columns(df, headers)
    
    frames.append(df)
    
    
df = pd.concat(frames, sort=False)
# Out:
# /Users/eric/proj/metatab-dev/metapack-dev/rowgenerators/rowgenerators/generator/csv.py:102: UserWarning: Date parsing error in read_csv. Trying again without parsing dates Exception: 'date_occurred' is not in list
#   'Exception: '+str(last_exception))

# %%
df.head().T
# Out:
#                                                                      0  \
#  RIN                                                            154619
#  Primary Key                                               2.01511e+08
#  Date Occurred                                  01/01/2015 12:00:00 AM
#  Time Occurred                                                    0220
#  Location                                        E 6TH ST / TRINITY ST
#  Area Command                                                       GE
#  Nature of Contact                                      VIEWED OFFENSE
#  Reason Desc                    NECESSARY TO EFFECT ARREST / DETENTION
#  R2R Level                                                           3
# Master Subject ID                                 459228703: 201510652
#  Subject Sex                                                         M
#  Subject Race                                                        W
#  Subject Ethnicity                                                   N
#  Subject Conduct Desc       SUSPECTED UNDER INFLUENCE OF ALCOHOL/DRUGS
#  Subject Resistance                    EMPTY HAND DEFENSIVE RESISTANCE
#  Weapon Used 1                 WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
#  Weapon Used 2                                                     NaN
# Weapon Used 3                                                      NaN
#  Weapon Used 4                                                     NaN
#  Weapon Used 5                                                     NaN
#  Number Shots                                                      NaN
#  Subject Effects                           NO COMPLAINT OF INJURY/PAIN
#  Effect on Officer                         NO COMPLAINT OF INJURY/PAIN
#  Officer Organization Desc                     GEORGE 600 REG I PATROL
#  Officer Commission Date                        05/17/2013 12:00:00 AM
# Officer Yrs of Service                                               2
#  X-Coordinate                                              3.11542e+06
#  Y-Coordinate                                              1.00704e+07
# CouncilDistrict                                                      9
# RIN                                                                NaN
# Primary Key                                                        NaN
# Date  Occurred                                                     NaN
# Time  Occurred                                                     NaN
# Location                                                           NaN
# Area  Command                                                      NaN
# Nature of Contact                                                  NaN
# Reason Desc                                                        NaN
# R2R Level                                                          NaN
# Subject  Sex                                                       NaN
# Subject  Race                                                      NaN
# Subject  Ethnicity                                                 NaN
# Subject Conduct Desc                                               NaN
# Subject Resistance                                                 NaN
# Weapon Used 1                                                      NaN
# Weapon Used 2                                                      NaN
# Weapon Used 4                                                      NaN
# Weapon Used 5                                                      NaN
# Number  Shots                                                      NaN
# Subject Effects                                                    NaN
# Effect on Officer                                                  NaN
# Officer  Organization Desc                                         NaN
# Officer  Commission Date                                           NaN
# X-Coordinate                                                       NaN
# Y-Coordinate                                                       NaN
# Council District                                                   NaN
# CENSUS_TRACT                                                       NaN
# COUNTY                                                             NaN
# Location 1                                                         NaN
# ZIP                                                                NaN
# county description                                                 NaN
#
#                                                                             1  \
#  RIN                                                                   154620
#  Primary Key                                                      2.01511e+08
#  Date Occurred                                         01/01/2015 12:00:00 AM
#  Time Occurred                                                           0225
#  Location                                               E 6TH ST / TRINITY ST
#  Area Command                                                              GE
#  Nature of Contact                                             VIEWED OFFENSE
#  Reason Desc                           NECESSARY TO EFFECT ARREST / DETENTION
#  R2R Level                                                                  3
# Master Subject ID                                        459228703: 201510652
#  Subject Sex                                                                M
#  Subject Race                                                               W
#  Subject Ethnicity                                                          N
#  Subject Conduct Desc              SUSPECTED UNDER INFLUENCE OF ALCOHOL/DRUGS
#  Subject Resistance         EMPTY HAND ACTIVE AGGRESSION; EMPTY HAND DEFEN...
#  Weapon Used 1                        WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
#  Weapon Used 2                                                            NaN
# Weapon Used 3                                                             NaN
#  Weapon Used 4                                                            NaN
#  Weapon Used 5                                                            NaN
#  Number Shots                                                             NaN
#  Subject Effects                                                 MINOR INJURY
#  Effect on Officer                                NO COMPLAINT OF INJURY/PAIN
#  Officer Organization Desc                            GEORGE 700 REG I PATROL
#  Officer Commission Date                               05/10/2002 12:00:00 AM
# Officer Yrs of Service                                                     13
#  X-Coordinate                                                     3.11542e+06
#  Y-Coordinate                                                     1.00704e+07
# CouncilDistrict                                                             9
# RIN                                                                       NaN
# Primary Key                                                               NaN
# Date  Occurred                                                            NaN
# Time  Occurred                                                            NaN
# Location                                                                  NaN
# Area  Command                                                             NaN
# Nature of Contact                                                         NaN
# Reason Desc                                                               NaN
# R2R Level                                                                 NaN
# Subject  Sex                                                              NaN
# Subject  Race                                                             NaN
# Subject  Ethnicity                                                        NaN
# Subject Conduct Desc                                                      NaN
# Subject Resistance                                                        NaN
# Weapon Used 1                                                             NaN
# Weapon Used 2                                                             NaN
# Weapon Used 4                                                             NaN
# Weapon Used 5                                                             NaN
# Number  Shots                                                             NaN
# Subject Effects                                                           NaN
# Effect on Officer                                                         NaN
# Officer  Organization Desc                                                NaN
# Officer  Commission Date                                                  NaN
# X-Coordinate                                                              NaN
# Y-Coordinate                                                              NaN
# Council District                                                          NaN
# CENSUS_TRACT                                                              NaN
# COUNTY                                                                    NaN
# Location 1                                                                NaN
# ZIP                                                                       NaN
# county description                                                        NaN
#
#                                                                      2  \
#  RIN                                                            155009
#  Primary Key                                               2.01511e+08
#  Date Occurred                                  01/01/2015 12:00:00 AM
#  Time Occurred
#  Location                                        E 6TH ST / TRINITY ST
#  Area Command                                                       GE
#  Nature of Contact                                      VIEWED OFFENSE
#  Reason Desc                    NECESSARY TO EFFECT ARREST / DETENTION
#  R2R Level                                                           3
# Master Subject ID                                 459228703: 201510652
#  Subject Sex                                                         M
#  Subject Race                                                        W
#  Subject Ethnicity                                                   N
#  Subject Conduct Desc       SUSPECTED UNDER INFLUENCE OF ALCOHOL/DRUGS
#  Subject Resistance                    EMPTY HAND DEFENSIVE RESISTANCE
#  Weapon Used 1                 WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
#  Weapon Used 2                                                     NaN
# Weapon Used 3                                                      NaN
#  Weapon Used 4                                                     NaN
#  Weapon Used 5                                                     NaN
#  Number Shots                                                      NaN
#  Subject Effects                           NO COMPLAINT OF INJURY/PAIN
#  Effect on Officer                         NO COMPLAINT OF INJURY/PAIN
#  Officer Organization Desc                     GEORGE 300 REG I PATROL
#  Officer Commission Date                        11/30/2012 12:00:00 AM
# Officer Yrs of Service                                               2
#  X-Coordinate                                              3.11542e+06
#  Y-Coordinate                                              1.00704e+07
# CouncilDistrict                                                      9
# RIN                                                                NaN
# Primary Key                                                        NaN
# Date  Occurred                                                     NaN
# Time  Occurred                                                     NaN
# Location                                                           NaN
# Area  Command                                                      NaN
# Nature of Contact                                                  NaN
# Reason Desc                                                        NaN
# R2R Level                                                          NaN
# Subject  Sex                                                       NaN
# Subject  Race                                                      NaN
# Subject  Ethnicity                                                 NaN
# Subject Conduct Desc                                               NaN
# Subject Resistance                                                 NaN
# Weapon Used 1                                                      NaN
# Weapon Used 2                                                      NaN
# Weapon Used 4                                                      NaN
# Weapon Used 5                                                      NaN
# Number  Shots                                                      NaN
# Subject Effects                                                    NaN
# Effect on Officer                                                  NaN
# Officer  Organization Desc                                         NaN
# Officer  Commission Date                                           NaN
# X-Coordinate                                                       NaN
# Y-Coordinate                                                       NaN
# Council District                                                   NaN
# CENSUS_TRACT                                                       NaN
# COUNTY                                                             NaN
# Location 1                                                         NaN
# ZIP                                                                NaN
# county description                                                 NaN
#
#                                                                             3  \
#  RIN                                                                   154764
#  Primary Key                                                       2.0152e+08
#  Date Occurred                                         01/02/2015 12:00:00 AM
#  Time Occurred                                                           0943
#  Location                                                        1900 FARO DR
#  Area Command                                                              HE
#  Nature of Contact                                            DISPATCHED CALL
#  Reason Desc                                  TO RESTRAIN FOR SUBJECTS SAFETY
#  R2R Level                                                                  3
# Master Subject ID                                        356649076: 201520457
#  Subject Sex                                                                F
#  Subject Race                                                               W
#  Subject Ethnicity                                                          N
#  Subject Conduct Desc       EDP/MENTALLY UNSTABLE; SUSPECTED UNDER INFLUEN...
#  Subject Resistance         VERBAL RESISTANCE/AGGRESSION; EMPTY HAND ACTIV...
#  Weapon Used 1                        WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
#  Weapon Used 2                                                            NaN
# Weapon Used 3                                                             NaN
#  Weapon Used 4                                                            NaN
#  Weapon Used 5                                                            NaN
#  Number Shots                                                             NaN
#  Subject Effects                                     COMPLAINT OF INJURY/PAIN
#  Effect on Officer                                   COMPLAINT OF INJURY/PAIN
#  Officer Organization Desc                           HENRY 100 REG III PATROL
#  Officer Commission Date                               06/20/2008 12:00:00 AM
# Officer Yrs of Service                                                      7
#  X-Coordinate                                                     3.12426e+06
#  Y-Coordinate                                                     1.00572e+07
# CouncilDistrict                                                             3
# RIN                                                                       NaN
# Primary Key                                                               NaN
# Date  Occurred                                                            NaN
# Time  Occurred                                                            NaN
# Location                                                                  NaN
# Area  Command                                                             NaN
# Nature of Contact                                                         NaN
# Reason Desc                                                               NaN
# R2R Level                                                                 NaN
# Subject  Sex                                                              NaN
# Subject  Race                                                             NaN
# Subject  Ethnicity                                                        NaN
# Subject Conduct Desc                                                      NaN
# Subject Resistance                                                        NaN
# Weapon Used 1                                                             NaN
# Weapon Used 2                                                             NaN
# Weapon Used 4                                                             NaN
# Weapon Used 5                                                             NaN
# Number  Shots                                                             NaN
# Subject Effects                                                           NaN
# Effect on Officer                                                         NaN
# Officer  Organization Desc                                                NaN
# Officer  Commission Date                                                  NaN
# X-Coordinate                                                              NaN
# Y-Coordinate                                                              NaN
# Council District                                                          NaN
# CENSUS_TRACT                                                              NaN
# COUNTY                                                                    NaN
# Location 1                                                                NaN
# ZIP                                                                       NaN
# county description                                                        NaN
#
#                                                                             4
#  RIN                                                                   154859
#  Primary Key                                                       2.0152e+08
#  Date Occurred                                         01/02/2015 12:00:00 AM
#  Time Occurred                                                           0943
#  Location                                                        1900 FARO DR
#  Area Command                                                              HE
#  Nature of Contact                                            DISPATCHED CALL
#  Reason Desc                                  IN CUSTODY, MAINTAINING CONTROL
#  R2R Level                                                                  3
# Master Subject ID                                        356649076: 201520457
#  Subject Sex                                                                F
#  Subject Race                                                               W
#  Subject Ethnicity                                                          N
#  Subject Conduct Desc       EDP/MENTALLY UNSTABLE; SUSPECTED UNDER INFLUEN...
#  Subject Resistance         VERBAL RESISTANCE/AGGRESSION; EMPTY HAND DEFEN...
#  Weapon Used 1                        WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
#  Weapon Used 2                                                            NaN
# Weapon Used 3                                                             NaN
#  Weapon Used 4                                                            NaN
#  Weapon Used 5                                                            NaN
#  Number Shots                                                             NaN
#  Subject Effects                                     COMPLAINT OF INJURY/PAIN
#  Effect on Officer                                NO COMPLAINT OF INJURY/PAIN
#  Officer Organization Desc                           HENRY 100 REG III PATROL
#  Officer Commission Date                               01/02/2009 12:00:00 AM
# Officer Yrs of Service                                                      6
#  X-Coordinate                                                     3.12426e+06
#  Y-Coordinate                                                     1.00572e+07
# CouncilDistrict                                                             3
# RIN                                                                       NaN
# Primary Key                                                               NaN
# Date  Occurred                                                            NaN
# Time  Occurred                                                            NaN
# Location                                                                  NaN
# Area  Command                                                             NaN
# Nature of Contact                                                         NaN
# Reason Desc                                                               NaN
# R2R Level                                                                 NaN
# Subject  Sex                                                              NaN
# Subject  Race                                                             NaN
# Subject  Ethnicity                                                        NaN
# Subject Conduct Desc                                                      NaN
# Subject Resistance                                                        NaN
# Weapon Used 1                                                             NaN
# Weapon Used 2                                                             NaN
# Weapon Used 4                                                             NaN
# Weapon Used 5                                                             NaN
# Number  Shots                                                             NaN
# Subject Effects                                                           NaN
# Effect on Officer                                                         NaN
# Officer  Organization Desc                                                NaN
# Officer  Commission Date                                                  NaN
# X-Coordinate                                                              NaN
# Y-Coordinate                                                              NaN
# Council District                                                          NaN
# CENSUS_TRACT                                                              NaN
# COUNTY                                                                    NaN
# Location 1                                                                NaN
# ZIP                                                                       NaN
# county description                                                        NaN

# %%
# Break up the subject_resistance string in to parts, and make a dummy variable for each one. 

def xform(v):
    """Make replacements on an individual code"""
    return v.strip().lower()\
                .replace('expired code-','')\
                .replace('/','_')\
                .replace(' ','_')\
                .replace('nan','none')\
                .replace('-','none')
                
    
def expand_codes(v):
    """Expand the codes in a subject_resistance value into a list"""
    return list(xform(e) for e in v.split(';'))
    
orig_sr = list(sorted(set(e.strip() for  r in list(df.subject_resistance.unique()) for e in str(r).split(';') )))

dummy_var_names = set( xform(e) for e in orig_sr)

for dmv in dummy_var_names:
    print(f"Add dummy var 'sr_{dmv}' ")
    df['sr_'+dmv] = df.subject_resistance.fillna('').apply(lambda v: True if dmv in expand_codes(v) else False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-729187caf35a> in <module>()
#      10     return list(xform(e) for e in v.split(';'))
#      11
# ---> 12 orig_sr = list(sorted(set(e.strip() for  r in list(df.subject_resistance.unique()) for e in str(r).split(';') )))
#      13
#      14 dummy_var_names = set( xform(e) for e in orig_sr)
#
# ~/opt/anaconda3/envs/data/lib/python3.6/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'subject_resistance'

# %%
df.sr_edged_weapon.sum()

# %%
sr_cols = [c for c in df.columns if c.startswith('sr_')]
t = df[ ['subject_resistance']+sr_cols]
t[t.subject_resistance.fillna('').str.contains('expired')].T

# %%
df[df.subject_resistance.fillna('').str.contains('expired')].subject_resistance.unique()
