# %%
import seaborn as sns
import metapack as mp
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display 

# %matplotlib inline
sns.set_context('notebook')
mp.jupyter.init()

# %load_ext autoreload
# %autoreload 2

# %%
pkg = mp.jupyter.open_package()
#pkg = mp.jupyter.open_source_package()
pkg
# Out:
# # Response to Resistance
# `austintexas.gov-response_to_resistance-1.1.1` Last Update: 2020-06-10T04:54:03
#
# _Austin Police Department response to police resistance incidents._
#
#
# ## Documentation Links
#
# * [Data Dictionary](https://data.austintexas.gov/Public-Safety/GUIDE-2017-R2R/27tg-e4dt/data) A spreadsheet with field definitions, for 2017
# * [R2R Datasets](https://data.austintexas.gov/browse?q=Response+To+Resistence&sortBy=relevance&page=1) A search on the Austin open data site for R2R datasets.
#
#
#
# ## Contacts
#
# * **Wrangler** [Eric Busboom](mailto:eric@civicknowledge.com), [Civic Knowledge](http://civicknowledge.com)
#
# ## Resources
#
# * ** [r2r_2015](data/r2r_2015.csv)**. Response to Resistance, 2015
# * ** [r2r_2016](data/r2r_2016.csv)**. Response to Resistance, 2016
# * ** [r2r_2017](data/r2r_2017.csv)**. Response to Resistance, 2017
# * ** [r2r_2018](data/r2r_2018.csv)**. Response to Resistance, 2018
# * ** [r2r_2015_2018](data/r2r_2015_2018.csv)**. Combined R2R files, 2015 to 2018

# %%
df = pkg.resource('r2r_2015').dataframe()
df.head().T
# Out:
#                                                                     0  \
# rin                                                            154619
# primary_key                                                 201510652
# date_occurred                                     2015-01-01 00:00:00
# time_occurred                                                    0220
# location                                        E 6TH ST / TRINITY ST
# area_command                                                       GE
# nature_of_contact                                      VIEWED OFFENSE
# reason_desc                    NECESSARY TO EFFECT ARREST / DETENTION
# r2r_level                                                           3
# master_subject_id                                459228703: 201510652
# subject_sex                                                         M
# subject_race                                                        W
# subject_ethnicity                                                   N
# subject_conduct_desc       SUSPECTED UNDER INFLUENCE OF ALCOHOL/DRUGS
# subject_resistance                    EMPTY HAND DEFENSIVE RESISTANCE
# weapon_used_1                 WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
# weapon_used_2                                                     NaN
# weapon_used_3                                                     NaN
# weapon_used_4                                                     NaN
# weapon_used_5                                                     NaN
# number_shots                                                      NaN
# subject_effects                           NO COMPLAINT OF INJURY/PAIN
# effect_on_officer                         NO COMPLAINT OF INJURY/PAIN
# officer_organization_desc                     GEORGE 600 REG I PATROL
# officer_commission_date                           2013-05-17 00:00:00
# officer_yrs_of_service                                              2
# x_coordinate                                              3.11542e+06
# y_coordinate                                              1.00704e+07
# council_district                                                    9
#
#                                                                            1  \
# rin                                                                   154620
# primary_key                                                        201510652
# date_occurred                                            2015-01-01 00:00:00
# time_occurred                                                           0225
# location                                               E 6TH ST / TRINITY ST
# area_command                                                              GE
# nature_of_contact                                             VIEWED OFFENSE
# reason_desc                           NECESSARY TO EFFECT ARREST / DETENTION
# r2r_level                                                                  3
# master_subject_id                                       459228703: 201510652
# subject_sex                                                                M
# subject_race                                                               W
# subject_ethnicity                                                          N
# subject_conduct_desc              SUSPECTED UNDER INFLUENCE OF ALCOHOL/DRUGS
# subject_resistance         EMPTY HAND ACTIVE AGGRESSION; EMPTY HAND DEFEN...
# weapon_used_1                        WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
# weapon_used_2                                                            NaN
# weapon_used_3                                                            NaN
# weapon_used_4                                                            NaN
# weapon_used_5                                                            NaN
# number_shots                                                             NaN
# subject_effects                                                 MINOR INJURY
# effect_on_officer                                NO COMPLAINT OF INJURY/PAIN
# officer_organization_desc                            GEORGE 700 REG I PATROL
# officer_commission_date                                  2002-05-10 00:00:00
# officer_yrs_of_service                                                    13
# x_coordinate                                                     3.11542e+06
# y_coordinate                                                     1.00704e+07
# council_district                                                           9
#
#                                                                     2  \
# rin                                                            155009
# primary_key                                                 201510652
# date_occurred                                     2015-01-01 00:00:00
# time_occurred
# location                                        E 6TH ST / TRINITY ST
# area_command                                                       GE
# nature_of_contact                                      VIEWED OFFENSE
# reason_desc                    NECESSARY TO EFFECT ARREST / DETENTION
# r2r_level                                                           3
# master_subject_id                                459228703: 201510652
# subject_sex                                                         M
# subject_race                                                        W
# subject_ethnicity                                                   N
# subject_conduct_desc       SUSPECTED UNDER INFLUENCE OF ALCOHOL/DRUGS
# subject_resistance                    EMPTY HAND DEFENSIVE RESISTANCE
# weapon_used_1                 WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
# weapon_used_2                                                     NaN
# weapon_used_3                                                     NaN
# weapon_used_4                                                     NaN
# weapon_used_5                                                     NaN
# number_shots                                                      NaN
# subject_effects                           NO COMPLAINT OF INJURY/PAIN
# effect_on_officer                         NO COMPLAINT OF INJURY/PAIN
# officer_organization_desc                     GEORGE 300 REG I PATROL
# officer_commission_date                           2012-11-30 00:00:00
# officer_yrs_of_service                                              2
# x_coordinate                                              3.11542e+06
# y_coordinate                                              1.00704e+07
# council_district                                                    9
#
#                                                                            3  \
# rin                                                                   154764
# primary_key                                                        201520457
# date_occurred                                            2015-01-02 00:00:00
# time_occurred                                                           0943
# location                                                        1900 FARO DR
# area_command                                                              HE
# nature_of_contact                                            DISPATCHED CALL
# reason_desc                                  TO RESTRAIN FOR SUBJECTS SAFETY
# r2r_level                                                                  3
# master_subject_id                                       356649076: 201520457
# subject_sex                                                                F
# subject_race                                                               W
# subject_ethnicity                                                          N
# subject_conduct_desc       EDP/MENTALLY UNSTABLE; SUSPECTED UNDER INFLUEN...
# subject_resistance         VERBAL RESISTANCE/AGGRESSION; EMPTY HAND ACTIV...
# weapon_used_1                        WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
# weapon_used_2                                                            NaN
# weapon_used_3                                                            NaN
# weapon_used_4                                                            NaN
# weapon_used_5                                                            NaN
# number_shots                                                             NaN
# subject_effects                                     COMPLAINT OF INJURY/PAIN
# effect_on_officer                                   COMPLAINT OF INJURY/PAIN
# officer_organization_desc                           HENRY 100 REG III PATROL
# officer_commission_date                                  2008-06-20 00:00:00
# officer_yrs_of_service                                                     7
# x_coordinate                                                     3.12426e+06
# y_coordinate                                                     1.00572e+07
# council_district                                                           3
#
#                                                                            4
# rin                                                                   154859
# primary_key                                                        201520457
# date_occurred                                            2015-01-02 00:00:00
# time_occurred                                                           0943
# location                                                        1900 FARO DR
# area_command                                                              HE
# nature_of_contact                                            DISPATCHED CALL
# reason_desc                                  IN CUSTODY, MAINTAINING CONTROL
# r2r_level                                                                  3
# master_subject_id                                       356649076: 201520457
# subject_sex                                                                F
# subject_race                                                               W
# subject_ethnicity                                                          N
# subject_conduct_desc       EDP/MENTALLY UNSTABLE; SUSPECTED UNDER INFLUEN...
# subject_resistance         VERBAL RESISTANCE/AGGRESSION; EMPTY HAND DEFEN...
# weapon_used_1                        WEAPONLESS (PRESSURE POINTS/KICKS/HAND)
# weapon_used_2                                                            NaN
# weapon_used_3                                                            NaN
# weapon_used_4                                                            NaN
# weapon_used_5                                                            NaN
# number_shots                                                             NaN
# subject_effects                                     COMPLAINT OF INJURY/PAIN
# effect_on_officer                                NO COMPLAINT OF INJURY/PAIN
# officer_organization_desc                           HENRY 100 REG III PATROL
# officer_commission_date                                  2009-01-02 00:00:00
# officer_yrs_of_service                                                     6
# x_coordinate                                                     3.12426e+06
# y_coordinate                                                     1.00572e+07
# council_district                                                           3

# %%
doc = pkg

from itertools import zip_longest

headers = []

# This will iterate through columns in roughtly the same time from 
# each dataset. The prevents a case where, for insance, the last dataset has a new column
# in an early group ( say, 5th column ) but it will end up at the end of the combined columns. 
# Whith this technique, it will end up near the 5th position. 

columns = [list(c['header'] for c in r.columns()) for r in doc.resources() if r.name != 'r2r_2015_2018']

for col_headers in columns:

    for c in col_headers:
        if c not in headers:
            headers.append(c)
            
print(headers)
# Out:
# ['rin', 'primary_key', 'date_occurred', 'time_occurred', 'location', 'area_command', 'nature_of_contact', 'reason_desc', 'r2r_level', 'master_subject_id', 'subject_sex', 'subject_race', 'subject_ethnicity', 'subject_conduct_desc', 'subject_resistance', 'weapon_used_1', 'weapon_used_2', 'weapon_used_3', 'weapon_used_4', 'weapon_used_5', 'number_shots', 'subject_effects', 'effect_on_officer', 'officer_organization_desc', 'officer_commission_date', 'officer_yrs_of_service', 'x_coordinate', 'y_coordinate', 'council_district', 'census_tract', 'county', 'location_1', 'zip', 'county_description']

# %%
def update_columns(df, headers):
    
    t = pd.DataFrame()
    
    for h in headers:
        if h in df.columns:
            t[h] = df[h]
        else:
            t[h] = None
            
frames = [] 

for r in doc.resources():
    if r.name == 'r2r_2015_2018':
        continue
            
    df = r.dataframe()
    
    
    update_columns(df, headers)
    
    frames.append(df)
    
    
df = pd.concat(frames, sort=False)

# %%
# Break up the subject_resistance string in to parts, and make a dummy variable for each one. 

def xform(v):
    """Make replacements on an individual code"""
    return v.strip().lower()\
                .replace('expired code-','')\
                .replace('/','_')\
                .replace(' ','_')\
                .replace('nan','none')\
                .replace('-','none')
                
    
def expand_codes(v):
    """Expand the codes in a subject_resistance value into a list"""
    return list(xform(e) for e in v.split(';'))
    
orig_sr = list(sorted(set(e.strip() for  r in list(df.subject_resistance.unique()) for e in str(r).split(';') )))

dummy_var_names = set( xform(e) for e in orig_sr)

for dmv in dummy_var_names:
    print(f"Add dummy var 'sr_{dmv}' ")
    df['sr_'+dmv] = df.subject_resistance.fillna('').apply(lambda v: True if dmv in expand_codes(v) else False)
# Out:
# Add dummy var 'sr_none'
# Add dummy var 'sr_empty_hand_defensive_resistance'
# Add dummy var 'sr_aggressive_resistance'
# Add dummy var 'sr_evading_fleeing_motor_vehicle'
# Add dummy var 'sr_verbal_resistance_aggression'
# Add dummy var 'sr_deadly_resistance'
# Add dummy var 'sr_not_resistant'
# Add dummy var 'sr_other'
# Add dummy var 'sr_passive_resistance'
# Add dummy var 'sr_empty_hand_active_aggression'
# Add dummy var 'sr_defensive_resistance'
# Add dummy var 'sr_edged_weapon'
# Add dummy var 'sr_firearm'
# Add dummy var 'sr_preparatory_resistance'

# %%
df.sr_edged_weapon.sum()
# Out:
# 95

# %%
sr_cols = [c for c in df.columns if c.startswith('sr_')]
t = df[ ['subject_resistance']+sr_cols]
t[t.subject_resistance.fillna('').str.contains('expired')].T
# Out:
#                                                                           0     \
# subject_resistance                  expired code-evading/fleeing motor vehicle
# sr_none                                                                  False
# sr_empty_hand_defensive_resistance                                       False
# sr_aggressive_resistance                                                 False
# sr_evading_fleeing_motor_vehicle                                          True
# sr_verbal_resistance_aggression                                          False
# sr_deadly_resistance                                                     False
# sr_not_resistant                                                         False
# sr_other                                                                 False
# sr_passive_resistance                                                    False
# sr_empty_hand_active_aggression                                          False
# sr_defensive_resistance                                                  False
# sr_edged_weapon                                                          False
# sr_firearm                                                               False
# sr_preparatory_resistance                                                False
#
#                                                   1     \
# subject_resistance                  expired code-other
# sr_none                                          False
# sr_empty_hand_defensive_resistance               False
# sr_aggressive_resistance                         False
# sr_evading_fleeing_motor_vehicle                 False
# sr_verbal_resistance_aggression                  False
# sr_deadly_resistance                             False
# sr_not_resistant                                 False
# sr_other                                          True
# sr_passive_resistance                            False
# sr_empty_hand_active_aggression                  False
# sr_defensive_resistance                          False
# sr_edged_weapon                                  False
# sr_firearm                                       False
# sr_preparatory_resistance                        False
#
#                                                                                  2     \
# subject_resistance                  expired code-verbal resistance/aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                               True
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                  True
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                        False
# sr_passive_resistance                                                           False
# sr_empty_hand_active_aggression                                                  True
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                                                                  3     \
# subject_resistance                  expired code-empty hand active aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                              False
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                 False
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                         True
# sr_passive_resistance                                                           False
# sr_empty_hand_active_aggression                                                  True
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                                                                  4     \
# subject_resistance                  expired code-verbal resistance/aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                              False
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                  True
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                        False
# sr_passive_resistance                                                           False
# sr_empty_hand_active_aggression                                                  True
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                                                                  5     \
# subject_resistance                  expired code-verbal resistance/aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                               True
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                  True
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                        False
# sr_passive_resistance                                                           False
# sr_empty_hand_active_aggression                                                 False
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                                                                  6     \
# subject_resistance                  expired code-empty hand active aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                               True
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                 False
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                        False
# sr_passive_resistance                                                           False
# sr_empty_hand_active_aggression                                                  True
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                                                             7     \
# subject_resistance                  expired code-empty hand defensive resistance
# sr_none                                                                    False
# sr_empty_hand_defensive_resistance                                          True
# sr_aggressive_resistance                                                   False
# sr_evading_fleeing_motor_vehicle                                           False
# sr_verbal_resistance_aggression                                            False
# sr_deadly_resistance                                                       False
# sr_not_resistant                                                           False
# sr_other                                                                   False
# sr_passive_resistance                                                      False
# sr_empty_hand_active_aggression                                            False
# sr_defensive_resistance                                                    False
# sr_edged_weapon                                                            False
# sr_firearm                                                                 False
# sr_preparatory_resistance                                                  False
#
#                                                                                  8     \
# subject_resistance                  expired code-verbal resistance/aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                               True
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                  True
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                        False
# sr_passive_resistance                                                           False
# sr_empty_hand_active_aggression                                                  True
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                                                                  9     \
# subject_resistance                  expired code-verbal resistance/aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                               True
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                  True
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                        False
# sr_passive_resistance                                                            True
# sr_empty_hand_active_aggression                                                 False
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                     ...  \
# subject_resistance                  ...
# sr_none                             ...
# sr_empty_hand_defensive_resistance  ...
# sr_aggressive_resistance            ...
# sr_evading_fleeing_motor_vehicle    ...
# sr_verbal_resistance_aggression     ...
# sr_deadly_resistance                ...
# sr_not_resistant                    ...
# sr_other                            ...
# sr_passive_resistance               ...
# sr_empty_hand_active_aggression     ...
# sr_defensive_resistance             ...
# sr_edged_weapon                     ...
# sr_firearm                          ...
# sr_preparatory_resistance           ...
#
#                                                                          3282  \
# subject_resistance                  expired code-empty hand active aggression
# sr_none                                                                 False
# sr_empty_hand_defensive_resistance                                      False
# sr_aggressive_resistance                                                False
# sr_evading_fleeing_motor_vehicle                                        False
# sr_verbal_resistance_aggression                                         False
# sr_deadly_resistance                                                    False
# sr_not_resistant                                                        False
# sr_other                                                                False
# sr_passive_resistance                                                   False
# sr_empty_hand_active_aggression                                          True
# sr_defensive_resistance                                                 False
# sr_edged_weapon                                                         False
# sr_firearm                                                              False
# sr_preparatory_resistance                                               False
#
#                                                                             3283  \
# subject_resistance                  expired code-empty hand defensive resistance
# sr_none                                                                    False
# sr_empty_hand_defensive_resistance                                          True
# sr_aggressive_resistance                                                   False
# sr_evading_fleeing_motor_vehicle                                           False
# sr_verbal_resistance_aggression                                            False
# sr_deadly_resistance                                                       False
# sr_not_resistant                                                           False
# sr_other                                                                   False
# sr_passive_resistance                                                      False
# sr_empty_hand_active_aggression                                            False
# sr_defensive_resistance                                                    False
# sr_edged_weapon                                                            False
# sr_firearm                                                                 False
# sr_preparatory_resistance                                                  False
#
#                                                                                  3284  \
# subject_resistance                  expired code-verbal resistance/aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                               True
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                  True
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                        False
# sr_passive_resistance                                                           False
# sr_empty_hand_active_aggression                                                 False
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                                                             3285  \
# subject_resistance                  expired code-empty hand defensive resistance
# sr_none                                                                    False
# sr_empty_hand_defensive_resistance                                          True
# sr_aggressive_resistance                                                   False
# sr_evading_fleeing_motor_vehicle                                           False
# sr_verbal_resistance_aggression                                            False
# sr_deadly_resistance                                                       False
# sr_not_resistant                                                           False
# sr_other                                                                   False
# sr_passive_resistance                                                      False
# sr_empty_hand_active_aggression                                            False
# sr_defensive_resistance                                                    False
# sr_edged_weapon                                                            False
# sr_firearm                                                                 False
# sr_preparatory_resistance                                                  False
#
#                                                                                  3286  \
# subject_resistance                  expired code-verbal resistance/aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                               True
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                  True
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                        False
# sr_passive_resistance                                                            True
# sr_empty_hand_active_aggression                                                 False
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                                                             3287  \
# subject_resistance                  expired code-empty hand defensive resistance
# sr_none                                                                    False
# sr_empty_hand_defensive_resistance                                          True
# sr_aggressive_resistance                                                   False
# sr_evading_fleeing_motor_vehicle                                           False
# sr_verbal_resistance_aggression                                            False
# sr_deadly_resistance                                                       False
# sr_not_resistant                                                           False
# sr_other                                                                   False
# sr_passive_resistance                                                      False
# sr_empty_hand_active_aggression                                            False
# sr_defensive_resistance                                                    False
# sr_edged_weapon                                                            False
# sr_firearm                                                                 False
# sr_preparatory_resistance                                                  False
#
#                                                                             3288  \
# subject_resistance                  expired code-empty hand defensive resistance
# sr_none                                                                    False
# sr_empty_hand_defensive_resistance                                          True
# sr_aggressive_resistance                                                   False
# sr_evading_fleeing_motor_vehicle                                           False
# sr_verbal_resistance_aggression                                            False
# sr_deadly_resistance                                                       False
# sr_not_resistant                                                           False
# sr_other                                                                   False
# sr_passive_resistance                                                      False
# sr_empty_hand_active_aggression                                            False
# sr_defensive_resistance                                                    False
# sr_edged_weapon                                                            False
# sr_firearm                                                                 False
# sr_preparatory_resistance                                                  False
#
#                                                                                  3289  \
# subject_resistance                  expired code-verbal resistance/aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                               True
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                  True
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                        False
# sr_passive_resistance                                                           False
# sr_empty_hand_active_aggression                                                 False
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                                                                  3290  \
# subject_resistance                  expired code-verbal resistance/aggression; exp...
# sr_none                                                                         False
# sr_empty_hand_defensive_resistance                                               True
# sr_aggressive_resistance                                                        False
# sr_evading_fleeing_motor_vehicle                                                False
# sr_verbal_resistance_aggression                                                  True
# sr_deadly_resistance                                                            False
# sr_not_resistant                                                                False
# sr_other                                                                        False
# sr_passive_resistance                                                           False
# sr_empty_hand_active_aggression                                                 False
# sr_defensive_resistance                                                         False
# sr_edged_weapon                                                                 False
# sr_firearm                                                                      False
# sr_preparatory_resistance                                                       False
#
#                                                                             3291
# subject_resistance                  expired code-empty hand defensive resistance
# sr_none                                                                    False
# sr_empty_hand_defensive_resistance                                          True
# sr_aggressive_resistance                                                   False
# sr_evading_fleeing_motor_vehicle                                           False
# sr_verbal_resistance_aggression                                            False
# sr_deadly_resistance                                                       False
# sr_not_resistant                                                           False
# sr_other                                                                   False
# sr_passive_resistance                                                      False
# sr_empty_hand_active_aggression                                            False
# sr_defensive_resistance                                                    False
# sr_edged_weapon                                                            False
# sr_firearm                                                                 False
# sr_preparatory_resistance                                                  False
#
# [15 rows x 3285 columns]

# %%
df[df.subject_resistance.fillna('').str.contains('expired')].subject_resistance.unique()
# Out:
# array(['expired code-evading/fleeing motor vehicle', 'expired code-other',
#        'expired code-verbal resistance/aggression; expired code-empty hand active aggression; expired code-empty hand defensive resistance',
#        'expired code-empty hand active aggression; expired code-other',
#        'expired code-verbal resistance/aggression; expired code-empty hand active aggression',
#        'expired code-verbal resistance/aggression; expired code-empty hand defensive resistance',
#        'expired code-empty hand active aggression; expired code-empty hand defensive resistance',
#        'expired code-empty hand defensive resistance',
#        'expired code-verbal resistance/aggression; expired code-passive resistance; expired code-empty hand defensive resistance',
#        'expired code-empty hand active aggression; expired code-empty hand defensive resistance; expired code-evading/fleeing motor vehicle',
#        'expired code-empty hand defensive resistance; expired code-evading/fleeing motor vehicle',
#        'expired code-empty hand defensive resistance; expired code-other',
#        'expired code-empty hand active aggression; expired code-evading/fleeing motor vehicle',
#        'expired code-empty hand active aggression',
#        'expired code-verbal resistance/aggression; expired code-passive resistance',
#        'expired code-firearm',
#        'expired code-passive resistance; expired code-empty hand defensive resistance',
#        'expired code-verbal resistance/aggression; expired code-empty hand defensive resistance; expired code-other',
#        'expired code-passive resistance; expired code-empty hand active aggression; expired code-empty hand defensive resistance',
#        'expired code-other; expired code-evading/fleeing motor vehicle',
#        'expired code-passive resistance; expired code-evading/fleeing motor vehicle',
#        'expired code-verbal resistance/aggression; expired code-empty hand defensive resistance; expired code-evading/fleeing motor vehicle',
#        'expired code-empty hand defensive resistance; expired code-firearm',
#        'expired code-passive resistance; expired code-empty hand defensive resistance; expired code-evading/fleeing motor vehicle',
#        'expired code-passive resistance; expired code-empty hand active aggression',
#        'expired code-verbal resistance/aggression; expired code-other',
#        'expired code-edged weapon; expired code-empty hand defensive resistance',
#        'expired code-verbal resistance/aggression; expired code-passive resistance; expired code-evading/fleeing motor vehicle',
#        'expired code-passive resistance',
#        'expired code-verbal resistance/aggression',
#        'expired code-passive resistance; expired code-other',
#        'expired code-edged weapon',
#        'expired code-empty hand active aggression; expired code-empty hand defensive resistance; expired code-other',
#        'expired code-passive resistance; expired code-edged weapon',
#        'expired code-verbal resistance/aggression; expired code-empty hand active aggression; expired code-other',
#        'expired code-verbal resistance/aggression; expired code-passive resistance; expired code-empty hand active aggression',
#        'expired code-empty hand active aggression; expired code-firearm',
#        'expired code-verbal resistance/aggression; expired code-empty hand active aggression; expired code-evading/fleeing motor vehicle',
#        'expired code-verbal resistance/aggression; expired code-passive resistance; expired code-other',
#        'expired code-verbal resistance/aggression; expired code-empty hand active aggression; expired code-edged weapon',
#        'expired code-empty hand active aggression; expired code-edged weapon',
#        'expired code-empty hand active aggression; expired code-edged weapon; expired code-empty hand defensive resistance',
#        'expired code-verbal resistance/aggression; expired code-edged weapon; expired code-empty hand defensive resistance',
#        'expired code-empty hand active aggression; expired code-empty hand defensive resistance; expired code-firearm',
#        'expired code-verbal resistance/aggression; expired code-edged weapon',
#        'DEFENSIVE RESISTANCE; expired code-verbal resistance/aggression; expired code-edged weapon',
#        'expired code-verbal resistance/aggression; expired code-firearm',
#        'expired code-edged weapon; expired code-other',
#        'expired code-empty hand defensive resistance; expired code-other; expired code-evading/fleeing motor vehicle',
#        'DEFENSIVE RESISTANCE; expired code-verbal resistance/aggression',
#        'expired code-firearm; expired code-other'], dtype=object)
